# %% [markdown]
# <a href="https://colab.research.google.com/github/Swara-24/AI-2020/blob/master/Q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q4) Take a 3 input and train for 6 input set and predict for the rest 2:

# %%
import numpy as np
 
class Perceptron(object):
 
    def __init__(self, no_of_inputs, threshold = 16, learning_rate = 0.01):
        self.threshold = threshold
        self.learning_rate = learning_rate
        self.weights = np.zeros(no_of_inputs + 1)
           
    def predict(self, inputs):
        summation = np.dot(inputs, self.weights[1:]) + self.weights[0]
        if summation > 0:
          activation = 1
        else:
          activation = 0            
        return activation
 
    def train(self, training_inputs, labels):
        for _ in range(self.threshold + 1):
            for inputs, label in zip(training_inputs, labels):
                prediction = self.predict(inputs)
                self.weights[1:] += self.learning_rate * (label - prediction) * inputs
                self.weights[0] += self.learning_rate * (label - prediction)
                print("Inputs : ", inputs, end="\t")
                print("Labels : ", label)
                print("Outputs : ", prediction)
                print("Weights : ", self.weights[1:])
                print("Bias : ", self.weights[0])

# %%
training_inputs = []
training_inputs.append(np.array([1, 1, 1]))
training_inputs.append(np.array([1, 1, 0]))
training_inputs.append(np.array([1, 0, 1]))
training_inputs.append(np.array([1, 0, 0]))
training_inputs.append(np.array([0, 1, 1]))
training_inputs.append(np.array([0, 1, 0]))
 
labels = np.array([1, 0, 0, 0, 0, 0])
 
perceptron = Perceptron(3)
perceptron.train(training_inputs, labels)
# Out:
# Inputs :  [1 1 1]	Labels :  1
# Outputs :  0
# Weights :  [0.01 0.01 0.01]
# Bias :  0.01
# Inputs :  [1 1 0]	Labels :  0
# Outputs :  1
# Weights :  [0.   0.   0.01]
# Bias :  0.0
# Inputs :  [1 0 1]	Labels :  0
# Outputs :  1
# Weights :  [-0.01  0.    0.  ]
# Bias :  -0.01
# Inputs :  [1 0 0]	Labels :  0
# Outputs :  0
# Weights :  [-0.01  0.    0.  ]
# Bias :  -0.01
# Inputs :  [0 1 1]	Labels :  0
# Outputs :  0
# Weights :  [-0.01  0.    0.  ]
# Bias :  -0.01
# Inputs :  [0 1 0]	Labels :  0
# Outputs :  0
# Weights :  [-0.01  0.    0.  ]
# Bias :  -0.01
# Inputs :  [1 1 1]	Labels :  1
# Outputs :  0
# Weights :  [0.   0.01 0.01]
# Bias :  0.0
# Inputs :  [1 1 0]	Labels :  0
# Outputs :  1
# Weights :  [-0.01  0.    0.01]
# Bias :  -0.01
# Inputs :  [1 0 1]	Labels :  0
# Outputs :  0
# Weights :  [-0.01  0.    0.01]
# Bias :  -0.01
# Inputs :  [1 0 0]	Labels :  0
# Outputs :  0
# Weights :  [-0.01  0.    0.01]
# Bias :  -0.01
# Inputs :  [0 1 1]	Labels :  0
# Outputs :  0
# ...

# %%
inputs = np.array([1, 1, 1])
perceptron.predict(inputs)
# Out:
# 1

# %%
inputs = np.array([0, 1, 0])
perceptron.predict(inputs)
# Out:
# 0

# %%
inputs = np.array([0, 0, 1])
perceptron.predict(inputs)
# Out:
# 0

# %%
inputs = np.array([0, 0, 0])
perceptron.predict(inputs)
# Out:
# 0
